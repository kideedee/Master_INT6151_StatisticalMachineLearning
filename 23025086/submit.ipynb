# %%
# !pip install numpy

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Gradient Descent

# %% [markdown]
# ## 1.2

# %%
def fx(var):
    return (var[0] - var[1] ** 2 - 3) ** 2 + (var[0] - var[1] - 1) ** 2


def fx_dx1(var):
    return 2 * (var[0] - var[1] ** 2 - 3) + 2 * (var[0] - var[1] - 1)


def fx_dx2(var):
    return -4 * var[1] * (var[0] - var[1] ** 2 - 3) - 2 * (var[0] - var[1] - 1)


def gradient_descent(x, lr=0.2, n_steps=3):
    # num_samples, num_features = x.shape
    # theta = np.zeros(num_features)
    print(f"Initializing k={0}, lr={lr}, x={x[0]}], y={fx(x[0])}")
    print("===================")
    predictions = np.array([[fx(x[0])]])
    for i in range(n_steps + 1):
        gradient_x1 = fx_dx1(x[i])
        gradient_x2 = fx_dx2(x[i])
        print(f"fx_dx1={round(gradient_x1, 3)}")
        print(f"fx_dx2={round(gradient_x2, 3)}")
        new_x1 = x[i][0] - lr * gradient_x1
        new_x2 = x[i][1] - lr * gradient_x2
        print(f"new_x1={round(new_x1, 3)}")
        print(f"new_x2={round(new_x2, 3)}")
        x = np.concatenate((x, np.array([[new_x1, new_x2]])))
        prediction = round(fx(x[i + 1]), 3)
        predictions = np.concatenate((predictions, [[prediction]]))
        print(f"k={i}, y={prediction}, x={x[i + 1]}")
        print("===================")

    return x, predictions, n_steps

# %%
x, y, n_steps = gradient_descent(x=np.full((1, 2), -0.5), lr=0.2, n_steps=3)
# Out:
# Initializing k=0, lr=0.2, x=[-0.5 -0.5]], y=15.0625
# ...
# fx_dx1=-9.5
# fx_dx2=-5.5
# new_x1=1.4
# new_x2=0.6
# k=0, y=3.882, x=[1.4 0.6]
# ...
# fx_dx1=-4.32
# fx_dx2=5.104
# new_x1=2.264
# new_x2=-0.421
# k=1, y=3.672, x=[ 2.264  -0.4208]
# ...
# fx_dx1=1.543
# fx_dx2=-4.906
# new_x1=1.955
# new_x2=0.56
# k=2, y=2.002, x=[1.95530906 0.56049677]
# ...
# fx_dx1=-1.928
# fx_dx2=2.257
# new_x1=2.341
# new_x2=0.109
# k=3, y=1.968, x=[2.34092317 0.10911794]
# ...

# %%
print(f"x: {x[1:]}")
print(f"fx: {y[1:]}")
plt.plot([i for i in range(1, n_steps + 1)], y[1:4], "r-", label="Gradient Descent")
# plt.title("The value of fx after updating GD of each step")
plt.xlabel("Step K")
plt.ylabel("Value of fx")
plt.xticks(n_steps)
plt.legend()
plt.show()
# Out:
# x: [[ 1.4         0.6       ]
#  [ 2.264      -0.4208    ]
#  [ 1.95530906  0.56049677]
#  [ 2.34092317  0.10911794]]
# fx: [[3.882]
#  [3.672]
#  [2.002]
#  [1.968]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 7
#       5 plt.xlabel("Step K")
#       6 plt.ylabel("Value of fx")
# ----> 7 plt.xticks(n_steps)
#       8 plt.legend()
#       9 plt.show()
#
# File ~/Projects/master/Master_StatisticalMachineLearning/venv/lib/python3.10/site-packages/matplotlib/pyplot.py:2060, in xticks(ticks, labels, minor, **kwargs)
#    2057         raise TypeError("xticks(): Parameter 'labels' can't be set "
#    2058                         "without setting 'ticks'")
#    2059 else:
# -> 2060     locs = ax.set_xticks(ticks, minor=minor)
#    2062 labels_out: list[Text] = []
#    2063 if labels is None:
#
# ...

# %% [markdown]
# ## 1.3

# %%
x_1, y_1, n_steps_1 = gradient_descent(x=np.full((1, 2), -0.5), lr=0.01, n_steps=10)
# Out:
# Initializing k=0, lr=0.01, x=[-0.5 -0.5]], y=15.0625
# ...
# fx_dx1=-9.5
# fx_dx2=-5.5
# new_x1=-0.405
# new_x2=-0.445
# k=0, y=13.903, x=[-0.405 -0.445]
# ...
# fx_dx1=-9.126
# fx_dx2=-4.493
# new_x1=-0.314
# new_x2=-0.4
# k=1, y=12.902, x=[-0.3137395  -0.40006615]
# ...
# fx_dx1=-8.775
# fx_dx2=-3.732
# new_x1=-0.226
# new_x2=-0.363
# k=2, y=12.019, x=[-0.22599018 -0.36274975]
# ...
# fx_dx1=-8.442
# fx_dx2=-3.145
# new_x1=-0.142
# new_x2=-0.331
# k=3, y=11.228, x=[-0.14157382 -0.33129614]
# ...
# fx_dx1=-8.123
# fx_dx2=-2.688
# new_x1=-0.06
# new_x2=-0.304
# k=4, y=10.513, x=[-0.06034165 -0.30441556]
# ...
# fx_dx1=-7.818
# fx_dx2=-2.327
# new_x1=0.018
# new_x2=-0.281
# k=5, y=9.862, x=[ 0.01783708 -0.28114106]
# ...
# fx_dx1=-7.524
# fx_dx2=-2.04
# new_x1=0.093
# new_x2=-0.261
# k=6, y=9.268, x=[ 0.09308158 -0.2607363 ]
# ...
# fx_dx1=-7.242
# fx_dx2=-1.81
# new_x1=0.166
# new_x2=-0.243
# k=7, y=8.722, x=[ 0.16550326 -0.24263335]
# ...
# fx_dx1=-6.97
# fx_dx2=-1.624
# new_x1=0.235
# new_x2=-0.226
# ...

# %%
x_2, y_2, n_steps_2 = gradient_descent(x=np.full((1, 2), -0.5), lr=0.05, n_steps=10)
# Out:
# Initializing k=0, lr=0.05, x=[-0.5 -0.5]], y=15.0625
# ...
# fx_dx1=-9.5
# fx_dx2=-5.5
# new_x1=-0.025
# new_x2=-0.225
# k=0, y=10.099, x=[-0.025 -0.225]
# ...
# fx_dx1=-7.751
# fx_dx2=-1.168
# new_x1=0.363
# new_x2=-0.167
# k=1, y=7.325, x=[ 0.3625625  -0.16659688]
# ...
# fx_dx1=-6.272
# fx_dx2=-0.834
# new_x1=0.676
# new_x2=-0.125
# k=2, y=5.513, x=[ 0.67616576 -0.12487841]
# ...
# fx_dx1=-5.077
# fx_dx2=-0.771
# new_x1=0.93
# new_x2=-0.086
# k=3, y=4.316, x=[ 0.93000423 -0.08634516]
# ...
# fx_dx1=-4.122
# fx_dx2=-0.75
# new_x1=1.136
# new_x2=-0.049
# k=4, y=3.517, x=[ 1.13611442 -0.04883465]
# ...
# fx_dx1=-3.363
# fx_dx2=-0.734
# new_x1=1.304
# new_x2=-0.012
# k=5, y=2.976, x=[ 1.30424655 -0.01211201]
# ...
# fx_dx1=-2.759
# fx_dx2=-0.715
# new_x1=1.442
# new_x2=0.024
# k=6, y=2.604, x=[1.44220071 0.023632  ]
# ...
# fx_dx1=-2.28
# fx_dx2=-0.69
# new_x1=1.556
# new_x2=0.058
# k=7, y=2.342, x=[1.55617962 0.05812345]
# ...
# fx_dx1=-1.898
# fx_dx2=-0.66
# new_x1=1.651
# new_x2=0.091
# k=8, y=2.156, x=[1.65109387 0.09110583]
# ...

# %%
# Generate x, y data for contour plot
x1 = np.linspace(-1, 4, 100)
x2 = np.linspace(-1, 2, 100)
X1, X2 = np.meshgrid(x1, x2)
Z = fx([X1, X2])
x_lr1 = np.array(x_1)
x_lr2 = np.array(x_2)

# Create contour plot
plt.figure(figsize=(8, 6))
plt.contour(X1, X2, Z, levels=np.linspace(0, 50, 50))

for i in range(1, x_lr1.shape[0] - 1):
    plt.arrow(x_lr1[i, 0], x_lr1[i, 1], x_lr1[i + 1, 0] - x_lr1[i + 1, 0], x_lr1[i + 1, 1] - x_lr1[i, 1], color='b',
              length_includes_head=True, head_width=0.1, head_length=0.05)

for i in range(1, x_lr2.shape[0] - 1):
    plt.arrow(x_lr2[i, 0], x_lr2[i, 1], x_lr2[i + 1, 0] - x_lr2[i + 1, 0], x_lr2[i + 1, 1] - x_lr2[i, 1], color='r',
              length_includes_head=True, head_width=0.1, head_length=0.05)

plt.plot(x_lr1[1:, 0], x_lr1[1:, 1], label=f'λ = {0.01}')
plt.plot(x_lr2[1:, 0], x_lr2[1:, 1], label=f'λ = {0.05}')

plt.xlabel('x1')
plt.ylabel('x2')
# plt.title('Contour Plot of f(x)')
plt.colorbar(label='f(x)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # 2. Coding

# %%
def add_noise_data(input_data, input_labels, n_points, mean, scale):
    """
    Create a noise verstion of the input data

    Params:
        input_data: base input data
        input_labels: base input labels
        n_points: the number of needed points
        mean, scale: the gaussian data
    """
    raw_X = []
    raw_labels = []

    noise = np.random.normal(loc=mean, scale=scale, size=(n_points, 2))
    for i in range(n_points):
        k = np.random.randint(len(input_data))

        raw_X.append([input_data[k][0] + noise[i][0],
                      input_data[k][1] + noise[i][1]])

        raw_labels.append(input_labels[k])

    return np.array(raw_X), np.array(raw_labels)

class LogisticRegression:
    def __init__(self, learning_rate=0.01, num_iterations=10000):
        self.learning_rate = learning_rate
        self.num_iterations = num_iterations
        self.weights = None
        self.bias = None

    def sigmoid(self, z):
        return 1 / (1 + np.exp(-z))

    def binary_cross_entropy_loss(self, y, y_pred):
        return -np.mean(y * np.log(y_pred) + (1 - y) * np.log(1 - y_pred))

    def error_calculation(self, y_pred, y_true):
        n = y_pred.shape[0]
        y_pred[np.where(y_pred >= 0.5)] = 1
        y_pred[np.where(y_pred < 0.5)] = 0
        return 1 / n * np.sum(np.square(y_pred - y_true))

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for i in range(self.num_iterations):
            linear_model = np.dot(X, self.weights) + self.bias
            y_predicted = self.sigmoid(linear_model)
            current_loss = self.binary_cross_entropy_loss(y, y_predicted)
            error = self.error_calculation(y_predicted, y)
            if error == 0:
                print(f"Epoch {i + 1}: Loss = {current_loss}, weights = {self.weights}, bias = {self.bias}, error = {error}")
                print(f"Done")
                break
            else:
                if current_loss <= 1e-5:
                    print(f"Traning failed with {i}!")

            dw = (1 / n_samples) * np.dot(X.T, (y_predicted - y))
            db = (1 / n_samples) * np.sum(y_predicted - y)

            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db

    def predict(self, X):
        linear_model = np.dot(X, self.weights) + self.bias
        y_predicted = self.sigmoid(linear_model)
        y_predicted_cls = [1 if i > 0.5 else 0 for i in y_predicted]
        return y_predicted_cls

# %% [markdown]
# # 2.2

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 0, 0, 1])
seeds = [0, 10, 20, 30, 40]
for seed in seeds:
    print(f"Seed {seed}")
    np.random.seed(seed)
    X_noise, y_noise = add_noise_data(X, y, 10, 0., 0.2)
    model = LogisticRegression()
    model.fit(X_noise, y_noise)
# Out:
# Seed 0
# Epoch 8: Loss = 0.6920308271208342, weights = [0.00439242 0.0020652 ], bias = -0.006000000000000002, error = 0.0
# Done
# Seed 10
# Epoch 16: Loss = 0.691508751449964, weights = [0.00321267 0.00406233], bias = -0.007, error = 0.0
# Done
# Seed 20
# Epoch 9: Loss = 0.6918644075116311, weights = [0.00144853 0.00429176], bias = -0.005, error = 0.0
# Done
# Seed 30
# Epoch 14: Loss = 0.691549479054199, weights = [0.00410118 0.00349619], bias = -0.005999999999999999, error = 0.0
# Done
# Seed 40
# Epoch 6: Loss = 0.6919740311348423, weights = [0.00176939 0.0031033 ], bias = -0.004, error = 0.0
# Done

# %% [markdown]
# # 2.3

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 0, 0, 1])
seeds = [0, 10, 20, 30, 40, 50]
N = [20, 50, 100, 200, 500]
for n in N:
    print("N = {0}".format(n))
    for seed in seeds:
        print(f"Seed {seed}")
        np.random.seed(seed)
        X_noise, y_noise = add_noise_data(X, y, n, 0., 0.2)
        model = LogisticRegression()
        model.fit(X_noise, y_noise)
# Out:
# N = 20
# Seed 0
# Epoch 10: Loss = 0.6912754015019116, weights = [0.00370807 0.00449467], bias = -0.005499999999999999, error = 0.0
# Done
# Seed 10
# Epoch 21: Loss = 0.6911547736212107, weights = [0.00359655 0.00377574], bias = -0.0069999999999999975, error = 0.0
# Done
# Seed 20
# Epoch 5: Loss = 0.6917656876848378, weights = [0.00140604 0.00357255], bias = -0.003999999999999999, error = 0.0
# Done
# Seed 30
# Epoch 9: Loss = 0.6917819607743897, weights = [0.0034688  0.00336421], bias = -0.0055000000000000005, error = 0.0
# Done
# Seed 40
# Epoch 8: Loss = 0.6921454902606926, weights = [0.00348442 0.00167261], bias = -0.003499999999999999, error = 0.0
# Done
# Seed 50
# Epoch 12: Loss = 0.6914934054557397, weights = [0.00281404 0.0020381 ], bias = -0.005000000000000001, error = 0.0
# Done
# N = 50
# Seed 0
# Epoch 26: Loss = 0.6914163324956182, weights = [0.00407259 0.00549423], bias = -0.007, error = 0.0
# Done
# Seed 10
# ...

# %% [markdown]
# # 2.4

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 0, 0, 1])
seeds = [0, 42, 100, 200]
N = [10, 20]
for n in N:
    print("N = {0}".format(n))
    for seed in seeds:
        print(f"Seed {seed}")
        np.random.seed(seed)
        X_noise, y_noise = add_noise_data(X, y, n, 0., 0.2)
        X_test, y_test = add_noise_data(X, y, n, 0., 0.3)
        model = LogisticRegression()
        model.fit(X_noise, y_noise)
        y_pred = model.sigmoid(np.dot(X_test, model.weights) + model.bias)
        print(f"Testing ERR: {model.error_calculation(y_test, y_pred)}")
# Out:
# N = 10
# Seed 0
# Epoch 8: Loss = 0.6920308271208342, weights = [0.00439242 0.0020652 ], bias = -0.006000000000000002, error = 0.0
# Done
# Testing ERR: 0.2492229234999087
# Seed 42
# Epoch 19: Loss = 0.6919778152917093, weights = [0.00517984 0.00446848], bias = -0.007000000000000001, error = 0.0
# Done
# Testing ERR: 0.2487887288655434
# Seed 100
# Epoch 6: Loss = 0.6923814473771099, weights = [0.00279542 0.0019416 ], bias = -0.004, error = 0.0
# Done
# Testing ERR: 0.24951790887025127
# Seed 200
# Epoch 10: Loss = 0.6913267276220819, weights = [0.00058061 0.0040636 ], bias = -0.005, error = 0.0
# Done
# Testing ERR: 0.24937473716793038
# N = 20
# Seed 0
# Epoch 10: Loss = 0.6912754015019116, weights = [0.00370807 0.00449467], bias = -0.005499999999999999, error = 0.0
# Done
# Testing ERR: 0.24930717610209163
# Seed 42
# Epoch 9: Loss = 0.6917940935377452, weights = [0.00453556 0.00289717], bias = -0.0055, error = 0.0
# Done
# Testing ERR: 0.2494460344324052
# Seed 100
# ...
